# %% [markdown]
# Home Sales Regression. Training Model
#
# Predict the final price of each home.
#
# target variable: SalePrice

# %%
import pandas as pd
homeprice_train = pd.read_csv("train.csv")
homeprice_test = pd.read_csv("test.csv")

# %%
homeprice_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
homeprice_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
homeprice_train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
homeprice_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns

# %%
plt.scatter(homeprice_train.PoolArea,homeprice_train.SalePrice)
plt.title("Price VS PoolArea")
# Out:
# Text(0.5, 1.0, 'Price VS PoolArea')

# %%
plt.scatter(homeprice_train['1stFlrSF'],homeprice_train.SalePrice)
plt.title("Price VS 1st FLR SF")
# Out:
# Text(0.5, 1.0, 'Price VS 1st FLR SF')

# %%
plt.scatter(homeprice_train.PoolArea,homeprice_train.SalePrice)
plt.title("Price VS Pool Area")
# Out:
# Text(0.5, 1.0, 'Price VS Pool Area')

# %%
plt.scatter(homeprice_train['2ndFlrSF'],homeprice_train.SalePrice)
plt.title("Price VS 2nd FLR SF")
# Out:
# Text(0.5, 1.0, 'Price VS 2nd FLR SF')

# %%
plt.scatter(homeprice_train.MSZoning,homeprice_train.SalePrice)
plt.title("Price VS MS Zoning")
# Out:
# Text(0.5, 1.0, 'Price VS MS Zoning')

# %% [markdown]
# Wow Fun

# %%
ax = sns.boxplot(data = homeprice_train, x = 'MSZoning', y = 'SalePrice')

# %%
conv_BsmtQual = [4 if values == 'Ex' else 3 if values == 'Gd' else 2 if values == 'TA' else 1 if values == 'Fa' else 0 for values in homeprice_train.BsmtQual]
homeprice_train['BsmtQual'] = conv_BsmtQual
plt.scatter(homeprice_train.BsmtQual,homeprice_train.SalePrice)
plt.title("Price VS BsmtQual")
# Out:
# Text(0.5, 1.0, 'Price VS BsmtQual')

# %%
plt.scatter(homeprice_train.MSSubClass,homeprice_train.SalePrice)
plt.title("Price VS MSSubClass")
# Out:
# Text(0.5, 1.0, 'Price VS MSSubClass')

# %%
conv_Street = [1 if values == 'Pave' else 0 for values in homeprice_train.Street]
homeprice_train['Street'] = conv_Street
plt.scatter(homeprice_train.Street,homeprice_train.SalePrice)
plt.title("Price VS Street")
# Out:
# Text(0.5, 1.0, 'Price VS Street')

# %%
plt.scatter(homeprice_train.OverallCond,homeprice_train.SalePrice)
plt.title("Price VS OverallCond")
# Out:
# Text(0.5, 1.0, 'Price VS OverallCond')

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
labels = homeprice_train['SalePrice']
train1 = homeprice_train[['LotArea','OverallQual','OverallCond','BsmtFinSF1','TotalBsmtSF','2ndFlrSF','TotRmsAbvGrd','GarageCars','WoodDeckSF']]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(train1, labels, test_size = 0.6, random_state = 1234)

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.score(x_test,y_test)
# Out:
# 0.6741514391293806
