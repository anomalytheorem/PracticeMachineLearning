# %%
#Install required packages
# !pip install pandas
# !pip install tensorflow
# !pip install sklearn
# !pip install matplotlib
# Out:
# Requirement already satisfied: pandas in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (1.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.20.3 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from pandas) (1.23.4)
# Requirement already satisfied: six>=1.5 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: tensorflow in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (2.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (15.0.6.1)
# Requirement already satisfied: termcolor>=1.1.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (2.2.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (2.11.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: setuptools in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: flatbuffers>=2.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (23.3.3)
# Requirement already satisfied: wrapt>=1.11.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (1.51.3)
# Requirement already satisfied: absl-py>=1.0.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: packaging in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (21.3)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (4.4.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: numpy>=1.20 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (1.23.4)
# Requirement already satisfied: astunparse>=1.6.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: six>=1.12.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (3.4.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.2.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.16.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.28.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from packaging->tensorflow) (3.0.9)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow) (6.0.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (1.26.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (2022.9.24)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow) (3.2.2)
# Requirement already satisfied: sklearn in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (0.0.post1)
# Requirement already satisfied: matplotlib in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (3.5.3)
# Requirement already satisfied: packaging>=20.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: cycler>=0.10 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: numpy>=1.17 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from matplotlib) (1.23.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
#Load up all the common functions. Required to execute other experiments
#Please reload if changes are made to the functions
# %run Common_Experiment_Functions.ipynb
# Out:
# Requirement already satisfied: pandas in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (1.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.20.3 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from pandas) (1.23.4)
# Requirement already satisfied: six>=1.5 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: tensorflow in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (2.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (15.0.6.1)
# Requirement already satisfied: h5py>=2.9.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (1.51.3)
# Requirement already satisfied: termcolor>=1.1.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (2.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (4.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: packaging in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (21.3)
# Requirement already satisfied: six>=1.12.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (2.11.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: numpy>=1.20 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (1.23.4)
# Requirement already satisfied: setuptools in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: flatbuffers>=2.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorflow) (23.3.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.28.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.16.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.2.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (0.6.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from packaging->tensorflow) (3.0.9)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow) (6.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (1.26.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow) (3.2.2)
# Requirement already satisfied: sklearn in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (0.0.post1)
# Requirement already satisfied: matplotlib in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (3.5.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: numpy>=1.17 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from matplotlib) (1.23.4)
# Requirement already satisfied: packaging>=20.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: six>=1.5 in /home/barry/anaconda3/envs/MachineLearning/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# ## 2.2 Epoch and Batch Sizes

# %%
#Initialize the measures
accuracy_measures = {}

for batch_size in range(16,128,16):
    
    #Load default configuration
    model_config = base_model_config()
    #Acquire and process input data
    X,Y = get_data()
    
    #set epoch to 20
    model_config["EPOCHS"]=20
    #Set batch size to experiment value
    model_config["BATCH_SIZE"] = batch_size
    model_name = "Batch-Size-" + str(batch_size)
    history=create_and_run_model(model_config,X,Y,model_name)
    
    accuracy_measures[model_name] = history.history["accuracy"]
# Out:
# ******************************************************
# Model: "Batch-Size-16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                160
#
#  Dense-Layer-1 (Dense)       (None, 64)                2112
#
#  Output-Layer (Dense)        (None, 3)                 195
#
# =================================================================
# Total params: 2,467
# Trainable params: 2,467
# Non-trainable params: 0
# _________________________________________________________________
#
# ******************************************************
# Model: "Batch-Size-32"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                160
#
#  Dense-Layer-1 (Dense)       (None, 64)                2112
#
#  Output-Layer (Dense)        (None, 3)                 195
#
# =================================================================
# Total params: 2,467
# Trainable params: 2,467
# Non-trainable params: 0
# _________________________________________________________________
#
# ******************************************************
# Model: "Batch-Size-48"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                160
#
#  Dense-Layer-1 (Dense)       (None, 64)                2112
#
#  Output-Layer (Dense)        (None, 3)                 195
#
# =================================================================
# Total params: 2,467
# Trainable params: 2,467
# Non-trainable params: 0
# _________________________________________________________________
#
# ******************************************************
# Model: "Batch-Size-64"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                160
#
#  Dense-Layer-1 (Dense)       (None, 64)                2112
#
#  Output-Layer (Dense)        (None, 3)                 195
#
# =================================================================
# Total params: 2,467
# Trainable params: 2,467
# Non-trainable params: 0
# _________________________________________________________________
#
# ******************************************************
# Model: "Batch-Size-80"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                160
#
#  Dense-Layer-1 (Dense)       (None, 64)                2112
#
#  Output-Layer (Dense)        (None, 3)                 195
#
# =================================================================
# Total params: 2,467
# Trainable params: 2,467
# Non-trainable params: 0
# _________________________________________________________________
#
# ******************************************************
# Model: "Batch-Size-96"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                160
#
#  Dense-Layer-1 (Dense)       (None, 64)                2112
#
#  Output-Layer (Dense)        (None, 3)                 195
#
# =================================================================
# Total params: 2,467
# Trainable params: 2,467
# Non-trainable params: 0
# _________________________________________________________________
#
# ******************************************************
# Model: "Batch-Size-112"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                160
#
#  Dense-Layer-1 (Dense)       (None, 64)                2112
#
#  Output-Layer (Dense)        (None, 3)                 195
#
# =================================================================
# Total params: 2,467
# Trainable params: 2,467
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_graph(accuracy_measures, "Compare Batch Size and Epoch")

# %% [markdown]
# ## 2.3. Layers in a Network

# %%
accuracy_measures = {}
layer_list =[]
for layer_count in range(1,6):
    
    #32 nodes in each layer
    layer_list.append(32)
    
    model_config = base_model_config()
    X,Y = get_data()
    
    model_config["HIDDEN_NODES"] = layer_list
    model_name = "Layers-" + str(layer_count)
    history=create_and_run_model(model_config,X,Y,model_name)
    
    accuracy_measures[model_name] = history.history["accuracy"]
# Out:
# ******************************************************
# Model: "Layers-1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                160
#
#  Output-Layer (Dense)        (None, 3)                 99
#
# =================================================================
# Total params: 259
# Trainable params: 259
# Non-trainable params: 0
# _________________________________________________________________
#
# ******************************************************
# Model: "Layers-2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                160
#
#  Dense-Layer-1 (Dense)       (None, 32)                1056
#
#  Output-Layer (Dense)        (None, 3)                 99
#
# =================================================================
# Total params: 1,315
# Trainable params: 1,315
# Non-trainable params: 0
# _________________________________________________________________
#
# ******************************************************
# Model: "Layers-3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                160
#
#  Dense-Layer-1 (Dense)       (None, 32)                1056
#
#  Dense-Layer-2 (Dense)       (None, 32)                1056
#
#  Output-Layer (Dense)        (None, 3)                 99
#
# =================================================================
# Total params: 2,371
# Trainable params: 2,371
# Non-trainable params: 0
# _________________________________________________________________
#
# ******************************************************
# Model: "Layers-4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                160
#
#  Dense-Layer-1 (Dense)       (None, 32)                1056
#
#  Dense-Layer-2 (Dense)       (None, 32)                1056
#
#  Dense-Layer-3 (Dense)       (None, 32)                1056
#
#  Output-Layer (Dense)        (None, 3)                 99
#
# =================================================================
# Total params: 3,427
# Trainable params: 3,427
# Non-trainable params: 0
# _________________________________________________________________
#
# ******************************************************
# Model: "Layers-5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                160
#
#  Dense-Layer-1 (Dense)       (None, 32)                1056
#
#  Dense-Layer-2 (Dense)       (None, 32)                1056
#
#  Dense-Layer-3 (Dense)       (None, 32)                1056
#
#  Dense-Layer-4 (Dense)       (None, 32)                1056
#
#  Output-Layer (Dense)        (None, 3)                 99
#
# =================================================================
# Total params: 4,483
# Trainable params: 4,483
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_graph(accuracy_measures, "Compare Hidden Layers")

# %% [markdown]
# ## 2.4 Nodes in a Layer

# %%
accuracy_measures = {}

for node_count in range(8,40,8):
    
    #have 2 hidden layers in the networks
    layer_list =[]
    for layer_count in range(2):
        layer_list.append(node_count)
    
    model_config = base_model_config()
    X,Y = get_data()
    
    model_config["HIDDEN_NODES"] = layer_list
    model_name = "Nodes-" + str(node_count)
    history=create_and_run_model(model_config,X,Y, model_name)
    
    accuracy_measures[model_name] = history.history["accuracy"]
# Out:
# ******************************************************
# Model: "Nodes-8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 8)                 40
#
#  Dense-Layer-1 (Dense)       (None, 8)                 72
#
#  Output-Layer (Dense)        (None, 3)                 27
#
# =================================================================
# Total params: 139
# Trainable params: 139
# Non-trainable params: 0
# _________________________________________________________________
#
# ******************************************************
# Model: "Nodes-16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 16)                80
#
#  Dense-Layer-1 (Dense)       (None, 16)                272
#
#  Output-Layer (Dense)        (None, 3)                 51
#
# =================================================================
# Total params: 403
# Trainable params: 403
# Non-trainable params: 0
# _________________________________________________________________
#
# ******************************************************
# Model: "Nodes-24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 24)                120
#
#  Dense-Layer-1 (Dense)       (None, 24)                600
#
#  Output-Layer (Dense)        (None, 3)                 75
#
# =================================================================
# Total params: 795
# Trainable params: 795
# Non-trainable params: 0
# _________________________________________________________________
#
# ******************************************************
# Model: "Nodes-32"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                160
#
#  Dense-Layer-1 (Dense)       (None, 32)                1056
#
#  Output-Layer (Dense)        (None, 3)                 99
#
# =================================================================
# Total params: 1,315
# Trainable params: 1,315
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_graph(accuracy_measures, "Compare Nodes in a Layer")

# %% [markdown]
# ## 2.5 Choosing Activation Functions

# %%
accuracy_measures = {}

activation_list = ['relu','sigmoid','tanh']

for activation in activation_list:
    
    model_config = base_model_config()
    X,Y = get_data()
    
    model_config["HIDDEN_ACTIVATION"] = activation
    model_name = "Model-" + activation
    history=create_and_run_model(model_config,X,Y,model_name)
    
    accuracy_measures["Model-" + activation] = history.history["accuracy"]
# Out:
# ******************************************************
# Model: "Model-relu"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                160
#
#  Dense-Layer-1 (Dense)       (None, 64)                2112
#
#  Output-Layer (Dense)        (None, 3)                 195
#
# =================================================================
# Total params: 2,467
# Trainable params: 2,467
# Non-trainable params: 0
# _________________________________________________________________
#
# ******************************************************
# Model: "Model-sigmoid"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                160
#
#  Dense-Layer-1 (Dense)       (None, 64)                2112
#
#  Output-Layer (Dense)        (None, 3)                 195
#
# =================================================================
# Total params: 2,467
# Trainable params: 2,467
# Non-trainable params: 0
# _________________________________________________________________
#
# ******************************************************
# Model: "Model-tanh"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                160
#
#  Dense-Layer-1 (Dense)       (None, 64)                2112
#
#  Output-Layer (Dense)        (None, 3)                 195
#
# =================================================================
# Total params: 2,467
# Trainable params: 2,467
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_graph(accuracy_measures, "Compare Activiation Functions")

# %% [markdown]
# ## 2.6. Weights Initialization

# %%
accuracy_measures = {}

initializer_list = ['random_normal','zeros','ones',"random_uniform"]
for initializer in initializer_list:
    
    model_config = base_model_config()
    X,Y = get_data()
    
    model_config["WEIGHTS_INITIALIZER"] = initializer
    model_name = "Model-" + initializer
    history=create_and_run_model(model_config,X,Y, model_name)
    
    accuracy_measures[model_name] = history.history["accuracy"]
# Out:
# ******************************************************
# Model: "Model-random_normal"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                160
#
#  Dense-Layer-1 (Dense)       (None, 64)                2112
#
#  Output-Layer (Dense)        (None, 3)                 195
#
# =================================================================
# Total params: 2,467
# Trainable params: 2,467
# Non-trainable params: 0
# _________________________________________________________________
#
# ******************************************************
# Model: "Model-zeros"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                160
#
#  Dense-Layer-1 (Dense)       (None, 64)                2112
#
#  Output-Layer (Dense)        (None, 3)                 195
#
# =================================================================
# Total params: 2,467
# Trainable params: 2,467
# Non-trainable params: 0
# _________________________________________________________________
#
# ******************************************************
# Model: "Model-ones"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                160
#
#  Dense-Layer-1 (Dense)       (None, 64)                2112
#
#  Output-Layer (Dense)        (None, 3)                 195
#
# =================================================================
# Total params: 2,467
# Trainable params: 2,467
# Non-trainable params: 0
# _________________________________________________________________
#
# ******************************************************
# Model: "Model-random_uniform"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                160
#
#  Dense-Layer-1 (Dense)       (None, 64)                2112
#
#  Output-Layer (Dense)        (None, 3)                 195
#
# =================================================================
# Total params: 2,467
# Trainable params: 2,467
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_graph(accuracy_measures, "Compare Weights Initializers")
