# %%
#Install required packages
# !pip install pandas
# !pip install tensorflow
# !pip install sklearn
# !pip install matplotlib
# Out:
# Requirement already satisfied: pandas in /home/barry/anaconda3/lib/python3.9/site-packages (1.4.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/barry/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/barry/anaconda3/lib/python3.9/site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.18.5 in /home/barry/anaconda3/lib/python3.9/site-packages (from pandas) (1.21.5)
# Requirement already satisfied: six>=1.5 in /home/barry/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: tensorflow in /home/barry/anaconda3/lib/python3.9/site-packages (2.11.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (2.11.2)
# Requirement already satisfied: wrapt>=1.11.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.51.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (15.0.6.1)
# Requirement already satisfied: packaging in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (21.3)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (4.3.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: numpy>=1.20 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.21.5)
# Requirement already satisfied: termcolor>=1.1.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (2.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (3.7.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: setuptools in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (63.4.1)
# Requirement already satisfied: flatbuffers>=2.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (23.3.3)
# Requirement already satisfied: six>=1.12.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.28.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (3.3.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.16.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.0.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (0.6.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/barry/anaconda3/lib/python3.9/site-packages (from packaging->tensorflow) (3.0.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/barry/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/barry/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (5.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/barry/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/barry/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/barry/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /home/barry/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (2022.9.14)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/barry/anaconda3/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow) (3.2.2)
# Requirement already satisfied: sklearn in /home/barry/anaconda3/lib/python3.9/site-packages (0.0.post1)
# Requirement already satisfied: matplotlib in /home/barry/anaconda3/lib/python3.9/site-packages (3.5.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/barry/anaconda3/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/barry/anaconda3/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /home/barry/anaconda3/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/barry/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: numpy>=1.17 in /home/barry/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: six>=1.5 in /home/barry/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
#Load up all the common functions. Required to execute other experiments
#Please reload if changes are made to the functions
# %run Common_Experiment_Functions.ipynb
# Out:
# Requirement already satisfied: pandas in /home/barry/anaconda3/lib/python3.9/site-packages (1.4.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/barry/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/barry/anaconda3/lib/python3.9/site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.18.5 in /home/barry/anaconda3/lib/python3.9/site-packages (from pandas) (1.21.5)
# Requirement already satisfied: six>=1.5 in /home/barry/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: tensorflow in /home/barry/anaconda3/lib/python3.9/site-packages (2.11.0)
# Requirement already satisfied: flatbuffers>=2.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (23.3.3)
# Requirement already satisfied: libclang>=13.0.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (15.0.6.1)
# Requirement already satisfied: numpy>=1.20 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.21.5)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (4.3.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.51.3)
# Requirement already satisfied: h5py>=2.9.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (3.7.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: termcolor>=1.1.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (2.2.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (2.11.2)
# Requirement already satisfied: packaging in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (21.3)
# Requirement already satisfied: absl-py>=1.0.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: six>=1.12.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: setuptools in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (63.4.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.16.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.28.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (3.3.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.0.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (1.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/barry/anaconda3/lib/python3.9/site-packages (from packaging->tensorflow) (3.0.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/barry/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/barry/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/barry/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/barry/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/barry/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /home/barry/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (2022.9.14)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/barry/anaconda3/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow) (3.2.2)
# Requirement already satisfied: sklearn in /home/barry/anaconda3/lib/python3.9/site-packages (0.0.post1)
# Requirement already satisfied: matplotlib in /home/barry/anaconda3/lib/python3.9/site-packages (3.5.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/barry/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in /home/barry/anaconda3/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: numpy>=1.17 in /home/barry/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/barry/anaconda3/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/barry/anaconda3/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/barry/anaconda3/lib/python3.9/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: six>=1.5 in /home/barry/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# ## 3.2. Batch Normalization

# %%
accuracy_measures = {}

normalization_list = ['none','batch']
for normalization in normalization_list:
    
    model_config = base_model_config()
    X,Y = get_data()
    
    model_config["NORMALIZATION"] = normalization
    model_name="Normalization-" + normalization
    history=create_and_run_model(model_config,X,Y,model_name)
    
    accuracy_measures[model_name] = history.history["accuracy"]
# Out:
# ******************************************************
# Model: "Normalization-none"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                160
#
#  Dense-Layer-1 (Dense)       (None, 64)                2112
#
#  Output-Layer (Dense)        (None, 3)                 195
#
# =================================================================
# Total params: 2,467
# Trainable params: 2,467
# Non-trainable params: 0
# _________________________________________________________________
#
# ******************************************************
# Model: "Normalization-batch"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                160
#
#  batch_normalization_1 (Batc  (None, 32)               128
#  hNormalization)
#
#  Dense-Layer-1 (Dense)       (None, 64)                2112
#
#  Output-Layer (Dense)        (None, 3)                 195
#
# =================================================================
# Total params: 2,595
# Trainable params: 2,531
# Non-trainable params: 64
# _________________________________________________________________

# %%
plot_graph(accuracy_measures, "Compare Normalization Techniques")

# %% [markdown]
# ## 3.4 Optimizers

# %%
accuracy_measures = {}

optimizer_list = ['sgd','rmsprop','adam','adagrad']
for optimizer in optimizer_list:
    
    model_config = base_model_config()
    X,Y = get_data()
    
    model_config["OPTIMIZER"] = optimizer
    model_name = "Optimizer-" + optimizer
    history=create_and_run_model(model_config,X,Y, model_name)
    
    accuracy_measures[model_name] = history.history["accuracy"]
# Out:
# ******************************************************
# Model: "Optimizer-sgd"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                160
#
#  Dense-Layer-1 (Dense)       (None, 64)                2112
#
#  Output-Layer (Dense)        (None, 3)                 195
#
# =================================================================
# Total params: 2,467
# Trainable params: 2,467
# Non-trainable params: 0
# _________________________________________________________________
#
# ******************************************************
# Model: "Optimizer-rmsprop"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                160
#
#  Dense-Layer-1 (Dense)       (None, 64)                2112
#
#  Output-Layer (Dense)        (None, 3)                 195
#
# =================================================================
# Total params: 2,467
# Trainable params: 2,467
# Non-trainable params: 0
# _________________________________________________________________
#
# ******************************************************
# Model: "Optimizer-adam"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                160
#
#  Dense-Layer-1 (Dense)       (None, 64)                2112
#
#  Output-Layer (Dense)        (None, 3)                 195
#
# =================================================================
# Total params: 2,467
# Trainable params: 2,467
# Non-trainable params: 0
# _________________________________________________________________
#
# ******************************************************
# Model: "Optimizer-adagrad"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                160
#
#  Dense-Layer-1 (Dense)       (None, 64)                2112
#
#  Output-Layer (Dense)        (None, 3)                 195
#
# =================================================================
# Total params: 2,467
# Trainable params: 2,467
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_graph(accuracy_measures, "Compare Optimizers")

# %% [markdown]
# ## 3.6. Learning Rates

# %%
accuracy_measures = {}

learning_rate_list = [0.001, 0.005,0.01,0.1,0.5]
for learning_rate in learning_rate_list:
    
    model_config = base_model_config()
    X,Y = get_data()
    
    model_config["LEARNING_RATE"] = learning_rate
    model_name="Learning-Rate-" + str(learning_rate)
    history=create_and_run_model(model_config,X,Y, model_name)
    
    #accuracy
    accuracy_measures[model_name] = history.history["accuracy"]
# Out:
# ******************************************************
# Model: "Learning-Rate-0.001"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                160
#
#  Dense-Layer-1 (Dense)       (None, 64)                2112
#
#  Output-Layer (Dense)        (None, 3)                 195
#
# =================================================================
# Total params: 2,467
# Trainable params: 2,467
# Non-trainable params: 0
# _________________________________________________________________
#
# ******************************************************
# Model: "Learning-Rate-0.005"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                160
#
#  Dense-Layer-1 (Dense)       (None, 64)                2112
#
#  Output-Layer (Dense)        (None, 3)                 195
#
# =================================================================
# Total params: 2,467
# Trainable params: 2,467
# Non-trainable params: 0
# _________________________________________________________________
#
# ******************************************************
# Model: "Learning-Rate-0.01"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                160
#
#  Dense-Layer-1 (Dense)       (None, 64)                2112
#
#  Output-Layer (Dense)        (None, 3)                 195
#
# =================================================================
# Total params: 2,467
# Trainable params: 2,467
# Non-trainable params: 0
# _________________________________________________________________
#
# ******************************************************
# Model: "Learning-Rate-0.1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                160
#
#  Dense-Layer-1 (Dense)       (None, 64)                2112
#
#  Output-Layer (Dense)        (None, 3)                 195
#
# =================================================================
# Total params: 2,467
# Trainable params: 2,467
# Non-trainable params: 0
# _________________________________________________________________
#
# ******************************************************
# Model: "Learning-Rate-0.5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                160
#
#  Dense-Layer-1 (Dense)       (None, 64)                2112
#
#  Output-Layer (Dense)        (None, 3)                 195
#
# =================================================================
# Total params: 2,467
# Trainable params: 2,467
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_graph(accuracy_measures, "Compare Learning Rates")
